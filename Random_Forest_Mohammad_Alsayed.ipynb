# %%
# Random Forest Regression

# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
# Importing the dataset
dataset = pd.read_csv('/content/HousePrices_HalfMil.csv')

# %%
dataset.head()
# Out:
#    Area  Garage  FirePlace  Baths  White Marble  Black Marble  Indian Marble  \
# 0   164       2          0      2             0             1              0
# 1    84       2          0      4             0             0              1
# 2   190       2          4      4             1             0              0
# 3    75       2          4      4             0             0              1
# 4   148       1          4      2             1             0              0
#
#    Floors  City  Solar  Electric  Fiber  Glass Doors  Swiming Pool  Garden  \
# 0       0     3      1         1      1            1             0       0
# 1       1     2      0         0      0            1             1       1
# 2       0     2      0         0      1            0             0       0
# 3       1     1      1         1      1            1             1       1
# 4       1     2      1         0      0            1             1       1
#
#    Prices
# 0   43800
# 1   37550
# 2   49500
# 3   50075
# 4   52400

# %%
X = dataset.drop('Prices', axis=1)
y = dataset['Prices']

# %%
X.shape
# Out:
# (500000, 15)

# %%
y.shape
# Out:
# (500000,)

# %%
from sklearn.model_selection import train_test_split
##X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state = 0)

# %% [markdown]
# Decision Tree Regressor

# %%
# import the regressor
from sklearn.tree import DecisionTreeRegressor

# create a regressor object
regressor1 = DecisionTreeRegressor(random_state = 0)

# fit the regressor with X and Y data
regressor1.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
y_pred1 = regressor1.predict(X_test)

# %%
mse1 = mean_squared_error(y_test, y_pred1)
mae2 = mean_absolute_error(y_test, y_pred1)

#Print the results
print('Decision Tree Regressorn:')
print('MSE:', mse1)
print('MAE:', mae2)
# Out:
# Decision Tree Regressorn:
# MSE: 109032.24375
# MAE: 234.78575

# %%
regressor1.score(X_test, y_test)
# Out:
# 0.9992544207655191

# %%
# import export_graphviz
from sklearn.tree import export_graphviz

# export the decision tree to a tree.dot file
# for visualizing the plot easily anywhere
export_graphviz(regressor1, out_file ='tree.png')

# %%
! dot -Tpdf tree.dot -o tree.pdf
# Out:
# Error: dot: can't open tree.dot

# %%
! xdot tree.dot
# Out:
# /bin/bash: line 1: xdot: command not found

# %%
! cd

# %%
# !dot -Tpng tree.dot -o tree1.png
# Out:
# Error: dot: can't open tree.dot

# %% [markdown]
# Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %%
# Predicting a new result
#y_pred = regressor.predict([[6.5,]])

# %%
y_pred = regressor.predict(X_test)

# %%
#Calculate the MSE and MAE
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
#Print the results
print('Random Forest Regression:')
print('MSE:', mse)
print('MAE:', mae)
# Out:
# Random Forest Regression:
# MSE: 62143.41875
# MAE: 190.82215

# %%
regressor.score(X_test, y_test)
# Out:
# 0.9995750537548701

# %%
regressor2 = RandomForestRegressor(n_estimators = 50, random_state = 0,max_depth=10)
regressor2.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=10, n_estimators=50, random_state=0)

# %%
y_pred2 = regressor2.predict(X_test)
y_pred2
# Out:
# array([28788.1908115 , 41614.32525288, 55128.57902759, ...,
#        40178.18314279, 55382.18723885, 42334.03827799])

# %%
#Calculate the MSE and MAE
mse = mean_squared_error(y_test, y_pred2)
mae = mean_absolute_error(y_test, y_pred2)
#Print the results
print('Random Forest Regression:')
print('MSE:', mse)
print('MAE:', mae)
# Out:
# Random Forest Regression:
# MSE: 2135714.6887288694
# MAE: 1172.0811133493917

# %%
print(regressor2.score(X_train, y_train))
print(regressor2.score(X_test, y_test))
# Out:
# 0.9859819125834846
# 0.9853956548271801

# %%
regressor = RandomForestRegressor(n_estimators = 20, random_state = 0)
regressor.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=20, random_state=0)

# %%
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([27166.25, 42538.75, 54061.25, ..., 42288.75, 55981.25, 43703.75])

# %%
#Calculate the MSE and MAE
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
#Print the results
print('Random Forest Regression:')
print('MSE:', mse)
print('MAE:', mae)
# Out:
# Random Forest Regression:
# MSE: 62143.41875
# MAE: 190.82215

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
# determine the best value of the RF hyperparameter
clf = GridSearchCV(RandomForestRegressor(), {
    'n_estimators': [10,20,30],
    'max_depth': [1,2,4,6,7,8,9,10],
}, cv=5, return_train_score=False)
clf.fit(X_train,y_train)

# %%
rfCV = pd.DataFrame(clf.cv_results_)

# %%
rfCV
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.678307      0.013400         0.016705        0.000388
# 1        1.533671      0.301295         0.035915        0.008863
# 2        2.280649      0.501859         0.045903        0.008016
# 3        1.632892      0.466568         0.029111        0.009942
# 4        2.566036      0.259607         0.048040        0.005146
# 5        4.539949      0.948199         0.071431        0.010221
# 6        2.355798      0.346499         0.035199        0.000336
# 7        4.688021      0.389221         0.069732        0.007333
# 8        6.981761      0.349006         0.102779        0.010114
# 9        3.299110      0.441395         0.049706        0.000956
# 10       7.156889      0.518789         0.097975        0.009108
# 11       9.773373      0.278621         0.145142        0.016431
# 12       3.565725      0.177973         0.059617        0.004503
# 13       7.173415      0.407248         0.109284        0.001254
# 14      10.691829      0.307487         0.168696        0.012558
# 15       4.055533      0.236024         0.071208        0.006924
# 16       8.110758      0.409502         0.128618        0.002083
# 17      12.218253      0.086974         0.189925        0.001213
# 18       4.418084      0.411071         0.077890        0.001117
# 19       8.636437      0.450970         0.149276        0.001030
# 20      12.937876      0.091384         0.229672        0.012611
# 21       4.688714      0.447737         0.091245        0.003846
# 22       9.587317      0.552972         0.181640        0.011706
# 23      14.073614      0.217152         0.267297        0.019047
#
#    param_max_depth param_n_estimators                                 params  \
# 0                1                 10   {'max_depth': 1, 'n_estimators': 10}
# 1                1                 20   {'max_depth': 1, 'n_estimators': 20}
# 2                1                 30   {'max_depth': 1, 'n_estimators': 30}
# 3                2                 10   {'max_depth': 2, 'n_estimators': 10}
# 4                2                 20   {'max_depth': 2, 'n_estimators': 20}
# 5                2                 30   {'max_depth': 2, 'n_estimators': 30}
# 6                4                 10   {'max_depth': 4, 'n_estimators': 10}
# 7                4                 20   {'max_depth': 4, 'n_estimators': 20}
# 8                4                 30   {'max_depth': 4, 'n_estimators': 30}
# 9                6                 10   {'max_depth': 6, 'n_estimators': 10}
# 10               6                 20   {'max_depth': 6, 'n_estimators': 20}
# 11               6                 30   {'max_depth': 6, 'n_estimators': 30}
# 12               7                 10   {'max_depth': 7, 'n_estimators': 10}
# 13               7                 20   {'max_depth': 7, 'n_estimators': 20}
# 14               7                 30   {'max_depth': 7, 'n_estimators': 30}
# 15               8                 10   {'max_depth': 8, 'n_estimators': 10}
# 16               8                 20   {'max_depth': 8, 'n_estimators': 20}
# 17               8                 30   {'max_depth': 8, 'n_estimators': 30}
# 18               9                 10   {'max_depth': 9, 'n_estimators': 10}
# 19               9                 20   {'max_depth': 9, 'n_estimators': 20}
# 20               9                 30   {'max_depth': 9, 'n_estimators': 30}
# 21              10                 10  {'max_depth': 10, 'n_estimators': 10}
# 22              10                 20  {'max_depth': 10, 'n_estimators': 20}
# 23              10                 30  {'max_depth': 10, 'n_estimators': 30}
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 0            0.386763           0.384055           0.381593
# 1            0.386764           0.384054           0.381593
# 2            0.386760           0.384055           0.381592
# 3            0.617212           0.618618           0.616690
# 4            0.617205           0.618619           0.616687
# 5            0.617201           0.618620           0.616688
# 6            0.868457           0.870160           0.873763
# 7            0.871891           0.868826           0.874364
# 8            0.873225           0.871015           0.875744
# 9            0.934030           0.935863           0.934594
# 10           0.934335           0.935632           0.933920
# 11           0.934427           0.935638           0.934457
# 12           0.950635           0.950771           0.950877
# 13           0.950482           0.951339           0.951176
# 14           0.950789           0.951222           0.951190
# 15           0.967160           0.967536           0.967476
# 16           0.967444           0.967846           0.967370
# 17           0.967590           0.967880           0.967778
# 18           0.977913           0.978102           0.977815
# 19           0.978115           0.978152           0.978072
# 20           0.978186           0.978297           0.978222
# 21           0.985225           0.985264           0.985115
# 22           0.985447           0.985589           0.985439
# 23           0.985535           0.985546           0.985521
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0            0.383690           0.383039         0.383828        0.001691
# 1            0.383689           0.383041         0.383828        0.001691
# 2            0.383689           0.383042         0.383828        0.001690
# 3            0.618721           0.617174         0.617683        0.000827
# 4            0.618720           0.617169         0.617680        0.000829
# 5            0.618721           0.617172         0.617680        0.000829
# 6            0.869635           0.871382         0.870680        0.001806
# 7            0.870541           0.871509         0.871426        0.001811
# 8            0.872830           0.871374         0.872837        0.001677
# 9            0.933707           0.935609         0.934761        0.000849
# 10           0.934610           0.935503         0.934800        0.000666
# 11           0.934286           0.935427         0.934847        0.000567
# 12           0.950330           0.950467         0.950616        0.000198
# 13           0.950856           0.950735         0.950917        0.000307
# 14           0.950943           0.950848         0.950998        0.000177
# 15           0.967259           0.966920         0.967270        0.000223
# 16           0.967388           0.967305         0.967470        0.000193
# 17           0.967508           0.967323         0.967616        0.000197
# 18           0.977491           0.977675         0.977799        0.000207
# 19           0.977778           0.977764         0.977976        0.000170
# 20           0.977889           0.977869         0.978093        0.000178
# 21           0.984950           0.984821         0.985075        0.000167
# 22           0.985281           0.985166         0.985384        0.000147
# 23           0.985337           0.985360         0.985460        0.000092
#
#     rank_test_score
# 0                23
# 1                22
# 2                24
# 3                19
# 4                21
# 5                20
# 6                18
# 7                17
# 8                16
# 9                15
# 10               14
# 11               13
# 12               12
# 13               11
# 14               10
# 15                9
# 16                8
# 17                7
# 18                6
# 19                5
# 20                4
# 21                3
# 22                2
# 23                1

# %%
rfCV[['param_n_estimators','params','mean_test_score']]
# Out:
#    param_n_estimators                                 params  mean_test_score
# 0                  10   {'max_depth': 1, 'n_estimators': 10}         0.383826
# 1                  20   {'max_depth': 1, 'n_estimators': 20}         0.383827
# 2                  30   {'max_depth': 1, 'n_estimators': 30}         0.383828
# 3                  10   {'max_depth': 2, 'n_estimators': 10}         0.617679
# 4                  20   {'max_depth': 2, 'n_estimators': 20}         0.617681
# 5                  30   {'max_depth': 2, 'n_estimators': 30}         0.617682
# 6                  10   {'max_depth': 4, 'n_estimators': 10}         0.872174
# 7                  20   {'max_depth': 4, 'n_estimators': 20}         0.872197
# 8                  30   {'max_depth': 4, 'n_estimators': 30}         0.872518
# 9                  10   {'max_depth': 6, 'n_estimators': 10}         0.934503
# 10                 20   {'max_depth': 6, 'n_estimators': 20}         0.934708
# 11                 30   {'max_depth': 6, 'n_estimators': 30}         0.934928
# 12                 10   {'max_depth': 7, 'n_estimators': 10}         0.950716
# 13                 20   {'max_depth': 7, 'n_estimators': 20}         0.950917
# 14                 30   {'max_depth': 7, 'n_estimators': 30}         0.951027
# 15                 10   {'max_depth': 8, 'n_estimators': 10}         0.967263
# 16                 20   {'max_depth': 8, 'n_estimators': 20}         0.967574
# 17                 30   {'max_depth': 8, 'n_estimators': 30}         0.967578
# 18                 10   {'max_depth': 9, 'n_estimators': 10}         0.977807
# 19                 20   {'max_depth': 9, 'n_estimators': 20}         0.978057
# 20                 30   {'max_depth': 9, 'n_estimators': 30}         0.978070
# 21                 10  {'max_depth': 10, 'n_estimators': 10}         0.985040
# 22                 20  {'max_depth': 10, 'n_estimators': 20}         0.985391
# 23                 30  {'max_depth': 10, 'n_estimators': 30}         0.985473

# %%
clf.best_params_
# Out:
# {'max_depth': 10, 'n_estimators': 30}

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestRegressor

# %%
clf1 = RandomizedSearchCV(RandomForestRegressor(), {
    'n_estimators': [10,20,30],
    'max_depth': [1,2,4,6,7,8,9,10],
}, cv=5, return_train_score=False)
clf1.fit(X_train,y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(),
#                    param_distributions={'max_depth': [1, 2, 4, 6, 7, 8, 9, 10],
#                                         'n_estimators': [10, 20, 30]})

# %%
clf1.best_params_
# Out:
# {'n_estimators': 20, 'max_depth': 10}

# %%
#clf1.cv_results_

# %%
RmCV = pd.DataFrame(clf1.cv_results_)

# %%
RmCV[['param_n_estimators','params','mean_test_score']]
# Out:
#   param_n_estimators                                 params  mean_test_score
# 0                 10  {'n_estimators': 10, 'max_depth': 10}         0.985023
# 1                 10   {'n_estimators': 10, 'max_depth': 8}         0.967276
# 2                 10   {'n_estimators': 10, 'max_depth': 4}         0.872623
# 3                 20   {'n_estimators': 20, 'max_depth': 6}         0.934457
# 4                 30   {'n_estimators': 30, 'max_depth': 6}         0.934994
# 5                 30   {'n_estimators': 30, 'max_depth': 4}         0.872691
# 6                 20   {'n_estimators': 20, 'max_depth': 8}         0.967513
# 7                 20  {'n_estimators': 20, 'max_depth': 10}         0.985375
# 8                 20   {'n_estimators': 20, 'max_depth': 1}         0.383828
# 9                 20   {'n_estimators': 20, 'max_depth': 4}         0.871822

# %%
#RmCV.head()

# %%
clf1.best_estimator_.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': 10,
#  'max_features': 1.0,
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 20,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
print("Best n_estimators:", clf1.best_estimator_.get_params()["n_estimators"])
print("Best max_depth:", clf1.best_estimator_.get_params()["max_depth"])
# Out:
# Best n_estimators: 20
# Best max_depth: 10

# %%
clf1.score(X_test, y_test)

# %%
regressor1.predict([[190,2,4,4,1,0,0,1,3,1,1,1,1,0,1]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([74025.])

# %%
a = int(input("What is the code of the Area?"))
# Out:
# What is the code of the Area?63

# %%
b = int(input("How many garages?"))
f = int(input("How many Fire Place?"))
c = int(input("How many bathrooms?"))
e = int(input("Does the house have White Marble?"))
d = int(input("Does the house have Black Marble?"))
e1 = int(input("Does the house have Indian marble?"))
floors = int(input("How many floors?"))
city = int(input("What is the code of the city?"))
solar = int(input("Does the house have solar?"))
Electric = int(input("Does the house have Electric?"))
Fiber = int(input("Does the house have Fiber?"))
GlassDoors = int(input("Does the house have Glass Doors?"))
SwimingPool = int(input("Does the house have Swiming Pool?"))
Garden = int(input("Does the house have Garden?"))
# Out:
# How many garages?3
# How many Fire Place?1
# How many bathrooms?3
# Does the house have White Marble?0
# Does the house have Black Marble?0
# Does the house have Indian marble?1
# How many floors?2
# What is the code of the city?3
# Does the house have solar?0
# Does the house have Electric?1
# Does the house have Fiber?0
# Does the house have Glass Doors?1
# Does the house have Swiming Pool?1
# Does the house have Garden?1

# %%
regressor1.predict([[a,b,f,c,e,d,e1,floors,city,solar,Electric,Fiber,GlassDoors,SwimingPool,Garden]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([43000.])

# %%
dataset.head()
# Out:
#    Area  Garage  FirePlace  Baths  White Marble  Black Marble  Indian Marble  \
# 0   164       2          0      2             0             1              0
# 1    84       2          0      4             0             0              1
# 2   190       2          4      4             1             0              0
# 3    75       2          4      4             0             0              1
# 4   148       1          4      2             1             0              0
#
#    Floors  City  Solar  Electric  Fiber  Glass Doors  Swiming Pool  Garden  \
# 0       0     3      1         1      1            1             0       0
# 1       1     2      0         0      0            1             1       1
# 2       0     2      0         0      1            0             0       0
# 3       1     1      1         1      1            1             1       1
# 4       1     2      1         0      0            1             1       1
#
#    Prices
# 0   43800
# 1   37550
# 2   49500
# 3   50075
# 4   52400
